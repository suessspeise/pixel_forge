# %% [markdown]
# # Deepfryer
#
# Toolkit for [a deepfried aesthetic](https://www.reddit.com/r/DeepFriedMemes).

# %%
import sys, os
sys.path.insert(0, os.path.abspath("../src"))
from deepfry import Deepfrier

# %%
[func for func in dir(Deepfrier()) if not func.startswith('__')]
# Out:
# ['add_blob',
#  'add_chromatic_aberration',
#  'add_glow_point',
#  'add_noise',
#  'blend_overlay',
#  'blur',
#  'jpeg_compression',
#  'multilayer_overlay',
#  'posterize',
#  'reduce_color_space',
#  'repeated_compression',
#  'saturation_contrast',
#  'tone_curving',
#  'unsharp_masking']
